# %% [markdown]
# # Credit Card Fraud Detection Using Deep Autoencoders
# ### Deep Learning Mini Project
#
# **Submitted By:** Kumsi Sravani
#
# **Roll Number:** 160623747305
#
# **Dataset:** Credit Card Fraud Detection Dataset
#
# **Algorithm:** Deep Autoencoder
#
# **Framework:** TensorFlow/Keras

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

print("Libraries Loaded Successfully")
# Out:
# Libraries Loaded Successfully

# %%
data = pd.read_csv("creditcard.csv")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print("Rows and Columns:")
print(data.shape)
# Out:
# Rows and Columns:
# (284807, 31)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
sns.countplot(x='Class', data=data)

plt.title("Normal vs Fraud Transactions")
plt.show()

# %%
scaler = StandardScaler()

data['Amount'] = scaler.fit_transform(
    data['Amount'].values.reshape(-1,1)
)

data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data = data.drop(['Time'], axis=1)

data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
normal_data = data[data.Class == 0]
fraud_data = data[data.Class == 1]

print("Normal Transactions:", len(normal_data))
print("Fraud Transactions:", len(fraud_data))
# Out:
# Normal Transactions: 284315
# Fraud Transactions: 492

# %%
X_normal = normal_data.drop('Class', axis=1)

X_fraud = fraud_data.drop('Class', axis=1)

# %%
X_train, X_test = train_test_split(
    X_normal,
    test_size=0.2,
    random_state=42
)

print("Training Data Shape:", X_train.shape)
print("Testing Data Shape:", X_test.shape)
# Out:
# Training Data Shape: (227452, 29)
# Testing Data Shape: (56863, 29)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

input_dim = X_train.shape[1]

input_layer = Input(shape=(input_dim,))

# Encoder
encoder = Dense(16, activation='relu')(input_layer)
encoder = Dense(8, activation='relu')(encoder)

# Decoder
decoder = Dense(16, activation='relu')(encoder)
decoder = Dense(input_dim, activation='linear')(decoder)

autoencoder = Model(inputs=input_layer,
                    outputs=decoder)

autoencoder.compile(
    optimizer='adam',
    loss='mse'
)

autoencoder.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 29)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 16)                  │             480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ...

# %%
history = autoencoder.fit(
    X_train,
    X_train,
    epochs=20,
    batch_size=256,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.6867 - val_loss: 0.5009
# Epoch 2/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.4436 - val_loss: 0.4231
# Epoch 3/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3974 - val_loss: 0.3927
# Epoch 4/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3745 - val_loss: 0.3740
# Epoch 5/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3609 - val_loss: 0.3638
# Epoch 6/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3524 - val_loss: 0.3569
# Epoch 7/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3463 - val_loss: 0.3502
# Epoch 8/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3419 - val_loss: 0.3470
# Epoch 9/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3381 - val_loss: 0.3440
# Epoch 10/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3274 - val_loss: 0.3212
# Epoch 11/20
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.3085 - val_loss: 0.3134
# ...

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history['loss'],
         label='Training Loss')

plt.plot(history.history['val_loss'],
         label='Validation Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Autoencoder Training Loss')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Autoencoder Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
reconstructions = autoencoder.predict(X_test)

mse = np.mean(
    np.power(X_test - reconstructions, 2),
    axis=1
)

print("Average Reconstruction Error:", np.mean(mse))
# Out:
# 1777/1777 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step
# Average Reconstruction Error: 0.28035594988692136

# %%
threshold = np.percentile(mse, 95)

print("Threshold:", threshold)
# Out:
# Threshold: 0.6844009536861468

# %%
fraud_reconstructions = autoencoder.predict(X_fraud)

fraud_mse = np.mean(
    np.power(X_fraud - fraud_reconstructions, 2),
    axis=1
)

print("Average Fraud Error:", np.mean(fraud_mse))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Average Fraud Error: 18.689405065913846

# %%
predictions = fraud_mse > threshold

print("Frauds Detected:", np.sum(predictions))
print("Total Fraud Cases:", len(fraud_mse))
# Out:
# Frauds Detected: 437
# Total Fraud Cases: 492

# %%
plt.figure(figsize=(10,5))

plt.hist(mse,
         bins=50,
         alpha=0.7,
         label='Normal Transactions')

plt.hist(fraud_mse,
         bins=50,
         alpha=0.7,
         label='Fraud Transactions')

plt.axvline(threshold,
            linestyle='--',
            label='Threshold')

plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.title('Fraud Detection using Autoencoder')

plt.legend()

plt.show()

# %%
# Credit Card Fraud Detection using Autoencoder

This project uses an Autoencoder-based anomaly detection approach to identify fraudulent credit card transactions. The model is trained using only legitimate transactions and detects fraud using reconstruction error.
